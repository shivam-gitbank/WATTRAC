# %%
#bronzw
import requests
import boto3
import json
import pandas as pd

API_URL = ""
S3_BUCKET = ""
SOURCE_NAME = ""

#----------------------------------------------------
# Calling API
#----------------------------------------------------
response = requests.get(API_URL, timeout = 220)
response.raise_for_status()
api_data = response.json()

#get the data from the API and store it in a json format at your S3 bucket
# the save should produces a repo in AWS which will be used as a bronze table raw artifact for hourly reads of aqi data of 30 min read of aqi data 
#finish this tomorrow
